# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
print(tf.__version__)
import tensorflow.keras as keras

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.datasets import imdb
from tensorflow.keras.layers import Input, Embedding, Conv1D, MaxPooling1D, \
  Dense, Activation, Dropout, GlobalMaxPooling1D, Add, BatchNormalization, \
  ReLU, Flatten, Activation

import numpy as np
from sklearn.model_selection import StratifiedKFold
# Out:
# 2.1.0-rc1

# %%
# Parameters:
# Word Embedding
max_features = 1000
maxlen = 400
embedding_dims = 125

# Convolution
kernel_size = 3  # filter length
filters = 125 # Authors use 250
pool_size = 4 

# Training
batch_size = 30
epochs = 5

# %%
print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')

print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
x_data = np.concatenate((x_train, x_test))
y_data = np.concatenate((y_train, y_test))
skf = StratifiedKFold(n_splits=5, random_state=42)
# Out:
# Loading data...
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# x_train shape: (25000, 400)
# x_test shape: (25000, 400)
# x_data shape: (50000, 400)
# y_data shape: (50000,)

# %%
# Block builder
def conv_block(inputs, filters, use_shortcut:bool=False, shortcut=None):
        conv_1 = Conv1D(filters=filters, kernel_size=3, padding='same')(inputs)
        bn_1 = BatchNormalization()(conv_1)
        relu_1 = ReLU()(bn_1)
        conv_2 = Conv1D(filters=filters, kernel_size=3, padding='same')(relu_1)
        bn_2 = BatchNormalization()(conv_2)
        relu_2 = ReLU()(bn_2)

        if shortcut is not None and use_shortcut:
            return Add()([inputs, shortcut])
        else:
            return relu_2
            
def selu_conv_block(inputs, filters, activation:str, use_shortcut:bool=False, shortcut=None, bnormalize:bool=False):
        conv_1 = Conv1D(filters=filters, kernel_size=3, padding='same')(inputs)
        if bnormalize:
          conv_1 = BatchNormalization()(conv_1)
        act_1 = Activation(activation=activation)(conv_1)
        conv_2 = Conv1D(filters=filters, kernel_size=3, padding='same')(act_1)
        if bnormalize:
          conv_1 = BatchNormalization()(conv_2)
        act_1 = Activation(activation=activation)(conv_2)

        if shortcut is not None and use_shortcut:
            return Add()([inputs, shortcut])
        else:
            return conv_2

# %%
# Source: https://stackoverflow.com/questions/56300553/what-is-k-max-pooling-how-to-implement-it-in-keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Layer, InputSpec
from tensorflow import sort 

class KMaxPooling(Layer):
    """
    K-max pooling layer that extracts the k-highest activations from a sequence (2nd dimension).
    TensorFlow backend.
    """
    def __init__(self, k=1, **kwargs):
        super().__init__(**kwargs)
        self.input_spec = InputSpec(ndim=3)
        self.k = k

    def compute_output_shape(self, input_shape):
        return (input_shape[0], (input_shape[2] * self.k))

    def call(self, inputs):

        # swap last two dimensions since top_k will be applied along the last dimension
        shifted_input = tf.transpose(inputs, [0, 2, 1])

        # extract top_k, returns two tensors [values, indices]
        top_k = tf.nn.top_k(shifted_input, k=self.k, sorted=True, name=None)[0]

        # return flattened output
        return Flatten()(top_k)

# %%
# Network Architecture
def create_VDCNN_model_1():
  # Conneau et al. Very Deep Convolutional Networks for Text Classification
  # We test the most shallow configuration, w/o shortcuts and w "VGG-like Downsampling"
  var_input = Input(shape=(400,))
  emb_layer = Embedding(max_features,
                      embedding_dims,
                      input_length=maxlen)(var_input)
  initial_conv = Conv1D(filters=64, kernel_size=3, padding='same')(emb_layer)
  # 2 x 64 Conv block
  conv_block_1 = conv_block(inputs=initial_conv, filters=64)
  conv_block_2 = conv_block(inputs=conv_block_1, filters=64)
    #Downsample
  pooling_layer_1 = MaxPooling1D(pool_size=3, strides=2)(conv_block_2)

  # 2 x 128 Conv block
  conv_block_3 = conv_block(inputs=pooling_layer_1, filters=128)
  conv_block_4 = conv_block(inputs=conv_block_3, filters=128)
    #Downsample
  pooling_layer_2 = MaxPooling1D(pool_size=3, strides=2)(conv_block_4)

  # 2 x 256 Conv block
  conv_block_5 = conv_block(inputs=pooling_layer_2, filters=256)
  conv_block_6 = conv_block(inputs=conv_block_5, filters=256)
  #Downsample
  pooling_layer_3 = MaxPooling1D(pool_size=3, strides=2)(conv_block_6)

  # 2 x 512 Conv block
  conv_block_7 = conv_block(inputs=pooling_layer_3, filters=512)
  conv_block_8 = conv_block(inputs=conv_block_7, filters=512)

  K_max_pooling = KMaxPooling(k=8)(conv_block_8)
  flattened = Flatten()(K_max_pooling)
  dense_layer_1 = Dense(2048, activation='relu')(flattened)
  dense_layer_2 = Dense(2048, activation='relu')(dense_layer_1)
  dense_layer_final = Dense(1, activation='sigmoid')(dense_layer_2)

  model = Model(inputs=var_input, outputs=dense_layer_final)
  model.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
  return model

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 400)]             0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 400, 125)          125000
# _________________________________________________________________
# conv1d_85 (Conv1D)           (None, 400, 64)           24064
# _________________________________________________________________
# conv1d_86 (Conv1D)           (None, 400, 64)           12352
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 400, 64)           256
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 400, 64)           0
# _________________________________________________________________
# conv1d_87 (Conv1D)           (None, 400, 64)           12352
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 400, 64)           256
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 400, 64)           0
# _________________________________________________________________
# conv1d_88 (Conv1D)           (None, 400, 64)           12352
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 400, 64)           256
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 400, 64)           0
# _________________________________________________________________
# conv1d_89 (Conv1D)           (None, 400, 64)           12352
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 400, 64)           256
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 400, 64)           0
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 199, 64)           0
# _________________________________________________________________
# conv1d_90 (Conv1D)           (None, 199, 128)          24704
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 199, 128)          512
# _________________________________________________________________
# re_lu_20 (ReLU)              (None, 199, 128)          0
# _________________________________________________________________
# conv1d_91 (Conv1D)           (None, 199, 128)          49280
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 199, 128)          512
# _________________________________________________________________
# re_lu_21 (ReLU)              (None, 199, 128)          0
# _________________________________________________________________
# conv1d_92 (Conv1D)           (None, 199, 128)          49280
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 199, 128)          512
# _________________________________________________________________
# re_lu_22 (ReLU)              (None, 199, 128)          0
# _________________________________________________________________
# conv1d_93 (Conv1D)           (None, 199, 128)          49280
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 199, 128)          512
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 199, 128)          0
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 99, 128)           0
# _________________________________________________________________
# conv1d_94 (Conv1D)           (None, 99, 256)           98560
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 99, 256)           1024
# _________________________________________________________________
# re_lu_24 (ReLU)              (None, 99, 256)           0
# _________________________________________________________________
# conv1d_95 (Conv1D)           (None, 99, 256)           196864
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 99, 256)           1024
# _________________________________________________________________
# re_lu_25 (ReLU)              (None, 99, 256)           0
# _________________________________________________________________
# conv1d_96 (Conv1D)           (None, 99, 256)           196864
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 99, 256)           1024
# _________________________________________________________________
# re_lu_26 (ReLU)              (None, 99, 256)           0
# _________________________________________________________________
# conv1d_97 (Conv1D)           (None, 99, 256)           196864
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 99, 256)           1024
# _________________________________________________________________
# re_lu_27 (ReLU)              (None, 99, 256)           0
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 49, 256)           0
# _________________________________________________________________
# conv1d_98 (Conv1D)           (None, 49, 512)           393728
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 49, 512)           2048
# _________________________________________________________________
# re_lu_28 (ReLU)              (None, 49, 512)           0
# _________________________________________________________________
# conv1d_99 (Conv1D)           (None, 49, 512)           786944
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 49, 512)           2048
# _________________________________________________________________
# re_lu_29 (ReLU)              (None, 49, 512)           0
# _________________________________________________________________
# conv1d_100 (Conv1D)          (None, 49, 512)           786944
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 49, 512)           2048
# _________________________________________________________________
# re_lu_30 (ReLU)              (None, 49, 512)           0
# _________________________________________________________________
# conv1d_101 (Conv1D)          (None, 49, 512)           786944
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 49, 512)           2048
# _________________________________________________________________
# re_lu_31 (ReLU)              (None, 49, 512)           0
# _________________________________________________________________
# k_max_pooling_5 (KMaxPooling (None, 4096)              0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2048)              8390656
# _________________________________________________________________
# dense_16 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 2049
# =================================================================
# Total params: 16,419,145
# Trainable params: 16,411,465
# Non-trainable params: 7,680
# _________________________________________________________________

# %%
for train, test in skf.split(x_data, y_data):
  target = create_VDCNN_model_1()
  target.fit(x_data[train], y_data[train],
            batch_size=batch_size,
            epochs=epochs,
            validation_data=(x_data[test], y_data[test]))
# Out:
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 82s 2ms/sample - loss: 0.5240 - accuracy: 0.7729 - val_loss: 0.3922 - val_accuracy: 0.8525
# Epoch 2/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.3093 - accuracy: 0.8672 - val_loss: 0.2923 - val_accuracy: 0.8834
# Epoch 3/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2824 - accuracy: 0.8820 - val_loss: 0.4130 - val_accuracy: 0.8798
# Epoch 4/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2662 - accuracy: 0.8891 - val_loss: 0.5471 - val_accuracy: 0.8213
# Epoch 5/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2490 - accuracy: 0.8978 - val_loss: 0.4035 - val_accuracy: 0.8556
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 82s 2ms/sample - loss: 0.5191 - accuracy: 0.7612 - val_loss: 1.2044 - val_accuracy: 0.6759
# Epoch 2/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.3080 - accuracy: 0.8695 - val_loss: 0.4169 - val_accuracy: 0.8324
# Epoch 3/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2809 - accuracy: 0.8814 - val_loss: 0.3536 - val_accuracy: 0.8536
# Epoch 4/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2624 - accuracy: 0.8921 - val_loss: 0.4801 - val_accuracy: 0.8125
# Epoch 5/5
# 40000/40000 [==============================] - 78s 2ms/sample - loss: 0.2451 - accuracy: 0.9000 - val_loss: 0.5030 - val_accuracy: 0.8018
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 82s 2ms/sample - loss: 0.5933 - accuracy: 0.7101 - val_loss: 0.4109 - val_accuracy: 0.8635
# Epoch 2/5
# 40000/40000 [==============================] - 78s 2ms/sample - loss: 0.3158 - accuracy: 0.8655 - val_loss: 0.3471 - val_accuracy: 0.8466
# Epoch 3/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2841 - accuracy: 0.8795 - val_loss: 0.3038 - val_accuracy: 0.8636
# Epoch 4/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2667 - accuracy: 0.8881 - val_loss: 0.8021 - val_accuracy: 0.6476
# Epoch 5/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2473 - accuracy: 0.8976 - val_loss: 0.4575 - val_accuracy: 0.8062
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 82s 2ms/sample - loss: 0.5702 - accuracy: 0.7456 - val_loss: 0.3270 - val_accuracy: 0.8604
# Epoch 2/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.3148 - accuracy: 0.8670 - val_loss: 0.8578 - val_accuracy: 0.7022
# Epoch 3/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2844 - accuracy: 0.8806 - val_loss: 0.3649 - val_accuracy: 0.8465
# Epoch 4/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2604 - accuracy: 0.8916 - val_loss: 0.3429 - val_accuracy: 0.8605
# Epoch 5/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2490 - accuracy: 0.8987 - val_loss: 0.2883 - val_accuracy: 0.8888
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 82s 2ms/sample - loss: 0.7228 - accuracy: 0.5853 - val_loss: 0.7395 - val_accuracy: 0.7070
# Epoch 2/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.3515 - accuracy: 0.8479 - val_loss: 0.2830 - val_accuracy: 0.8804
# Epoch 3/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.3005 - accuracy: 0.8724 - val_loss: 0.2785 - val_accuracy: 0.8876
# Epoch 4/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2807 - accuracy: 0.8844 - val_loss: 0.6034 - val_accuracy: 0.8279
# Epoch 5/5
# 40000/40000 [==============================] - 77s 2ms/sample - loss: 0.2630 - accuracy: 0.8916 - val_loss: 0.2705 - val_accuracy: 0.8963

# %%
# Network Architecture
def create_VDCNN_model_2():
# Conneau et al. Very Deep Convolutional Networks for Text Classification
# We test the most shallow configuration, w/o shortcuts and w "VGG-like Downsampling"
# Now with SELU Convolutional blocks: Replace BN and ReLU layers for having the conv layer with SELU activation
  var_input = Input(shape=(400,))
  emb_layer = Embedding(max_features,
                      embedding_dims,
                      input_length=maxlen)(var_input)
  initial_conv = Conv1D(filters=64, kernel_size=3, padding='same')(emb_layer)
  # 2 x 64 Conv block
  conv_block_1 = selu_conv_block(inputs=initial_conv, filters=64, activation='selu', bnormalize=False)
  conv_block_2 = selu_conv_block(inputs=conv_block_1, filters=64, activation='selu', bnormalize=False)
  #Downsample
  pooling_layer_1 = MaxPooling1D(pool_size=3, strides=2)(conv_block_2)

  # 2 x 128 Conv block
  conv_block_3 = selu_conv_block(inputs=pooling_layer_1, filters=128, activation='selu', bnormalize=False)
  conv_block_4 = selu_conv_block(inputs=conv_block_3, filters=128, activation='selu', bnormalize=False)
  #Downsample
  pooling_layer_2 = MaxPooling1D(pool_size=3, strides=2)(conv_block_4)

  # 2 x 256 Conv block
  conv_block_5 = selu_conv_block(inputs=pooling_layer_2, filters=256, activation='selu', bnormalize=False)
  conv_block_6 = selu_conv_block(inputs=conv_block_5, filters=256, activation='selu', bnormalize=False)
  #Downsample
  pooling_layer_3 = MaxPooling1D(pool_size=3, strides=2)(conv_block_6)

  # 2 x 512 Conv block
  conv_block_7 = selu_conv_block(inputs=pooling_layer_3, filters=512, activation='selu', bnormalize=False)
  conv_block_8 = selu_conv_block(inputs=conv_block_7, filters=512, activation='selu', bnormalize=False)

  K_max_pooling = KMaxPooling(k=8)(conv_block_8)
  flattened = Flatten()(K_max_pooling)
  dense_layer_1 = Dense(2048, activation='selu')(flattened)
  dense_layer_2 = Dense(2048, activation='selu')(dense_layer_1)
  dense_layer_final = Dense(1, activation='sigmoid')(dense_layer_2)

  model2 = Model(inputs=var_input, outputs=dense_layer_final)
  model2.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
  return model2

# %%
for train, test in skf.split(x_data, y_data):
  target = create_VDCNN_model_2()
  target.fit(x_data[train], y_data[train],
            batch_size=batch_size,
            epochs=epochs,
            validation_data=(x_data[test], y_data[test]))
# Out:
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 62s 2ms/sample - loss: 2.5941 - accuracy: 0.6117 - val_loss: 0.4308 - val_accuracy: 0.7983
# Epoch 2/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.3950 - accuracy: 0.8272 - val_loss: 0.3224 - val_accuracy: 0.8634
# Epoch 3/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.3454 - accuracy: 0.8533 - val_loss: 0.5413 - val_accuracy: 0.8331
# Epoch 4/5
# 40000/40000 [==============================] - 60s 2ms/sample - loss: 0.3486 - accuracy: 0.8558 - val_loss: 0.2961 - val_accuracy: 0.8758
# Epoch 5/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 5699142.9696 - accuracy: 0.6140 - val_loss: 617.3280 - val_accuracy: 0.5011
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 62s 2ms/sample - loss: 2.1372 - accuracy: 0.6626 - val_loss: 0.3826 - val_accuracy: 0.8314
# Epoch 2/5
# 40000/40000 [==============================] - 60s 2ms/sample - loss: 0.3652 - accuracy: 0.8416 - val_loss: 0.3857 - val_accuracy: 0.8234
# Epoch 3/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.3469 - accuracy: 0.8545 - val_loss: 0.3219 - val_accuracy: 0.8641
# Epoch 4/5
# 40000/40000 [==============================] - 60s 2ms/sample - loss: 114200.8456 - accuracy: 0.8009 - val_loss: 0.8753 - val_accuracy: 0.5000
# Epoch 5/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.7382 - accuracy: 0.5012 - val_loss: 0.6959 - val_accuracy: 0.5000
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 62s 2ms/sample - loss: 3.3564 - accuracy: 0.7386 - val_loss: 0.3646 - val_accuracy: 0.8420
# Epoch 2/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.3546 - accuracy: 0.8472 - val_loss: 0.3070 - val_accuracy: 0.8697
# Epoch 3/5
# 40000/40000 [==============================] - 60s 2ms/sample - loss: 0.3193 - accuracy: 0.8624 - val_loss: 0.3206 - val_accuracy: 0.8670
# Epoch 4/5
# 40000/40000 [==============================] - 60s 2ms/sample - loss: 0.3240 - accuracy: 0.8623 - val_loss: 0.2770 - val_accuracy: 0.8844
# Epoch 5/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 34037778.5428 - accuracy: 0.8396 - val_loss: 0.6981 - val_accuracy: 0.5000
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 62s 2ms/sample - loss: 2.4642 - accuracy: 0.5427 - val_loss: 0.5649 - val_accuracy: 0.7150
# Epoch 2/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.5074 - accuracy: 0.7568 - val_loss: 0.4546 - val_accuracy: 0.7920
# Epoch 3/5
# 40000/40000 [==============================] - 60s 2ms/sample - loss: 0.4605 - accuracy: 0.7983 - val_loss: 0.3578 - val_accuracy: 0.8458
# Epoch 4/5
# 40000/40000 [==============================] - 60s 2ms/sample - loss: 13934752.8728 - accuracy: 0.5442 - val_loss: 0.9091 - val_accuracy: 0.5000
# Epoch 5/5
# 40000/40000 [==============================] - 60s 2ms/sample - loss: 1.1533 - accuracy: 0.5013 - val_loss: 0.7605 - val_accuracy: 0.5000
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 61s 2ms/sample - loss: 11.8890 - accuracy: 0.5371 - val_loss: 0.5137 - val_accuracy: 0.7643
# Epoch 2/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.6808 - accuracy: 0.6982 - val_loss: 0.4196 - val_accuracy: 0.8175
# Epoch 3/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.3850 - accuracy: 0.8304 - val_loss: 0.3386 - val_accuracy: 0.8509
# Epoch 4/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 0.3752 - accuracy: 0.8389 - val_loss: 0.3126 - val_accuracy: 0.8627
# Epoch 5/5
# 40000/40000 [==============================] - 60s 1ms/sample - loss: 81859562.2898 - accuracy: 0.7070 - val_loss: 751.2313 - val_accuracy: 0.5000

# %%
# Network Architecture
def create_VDCNN_model_3():
  # Conneau et al. Very Deep Convolutional Networks for Text Classification
  # We test the most shallow configuration, w/o shortcuts and w "VGG-like Downsampling"
  # Now with SELU Convolutional blocks: Replace RELU with SELU (keep Batch Normalization)
  var_input = Input(shape=(400,))
  emb_layer = Embedding(max_features,
                      embedding_dims,
                      input_length=maxlen)(var_input)
  initial_conv = Conv1D(filters=64, kernel_size=3, padding='same')(emb_layer)
  # 2 x 64 Conv block
  conv_block_1 = selu_conv_block(inputs=initial_conv, filters=64, activation='selu', bnormalize=True)
  conv_block_2 = selu_conv_block(inputs=conv_block_1, filters=64, activation='selu', bnormalize=True)
  #Downsample
  pooling_layer_1 = MaxPooling1D(pool_size=3, strides=2)(conv_block_2)

  # 2 x 128 Conv block
  conv_block_3 = selu_conv_block(inputs=pooling_layer_1, filters=128, activation='selu', bnormalize=True)
  conv_block_4 = selu_conv_block(inputs=conv_block_3, filters=128, activation='selu', bnormalize=True)
  #Downsample
  pooling_layer_2 = MaxPooling1D(pool_size=3, strides=2)(conv_block_4)

  # 2 x 256 Conv block
  conv_block_5 = selu_conv_block(inputs=pooling_layer_2, filters=256, activation='selu', bnormalize=True)
  conv_block_6 = selu_conv_block(inputs=conv_block_5, filters=256, activation='selu', bnormalize=True)
  #Downsample
  pooling_layer_3 = MaxPooling1D(pool_size=3, strides=2)(conv_block_6)

  # 2 x 512 Conv block
  conv_block_7 = selu_conv_block(inputs=pooling_layer_3, filters=512, activation='selu', bnormalize=True)
  conv_block_8 = selu_conv_block(inputs=conv_block_7, filters=512, activation='selu', bnormalize=True)

  K_max_pooling = KMaxPooling(k=8)(conv_block_8)
  flattened = Flatten()(K_max_pooling)
  dense_layer_1 = Dense(2048, activation='selu')(flattened)
  dense_layer_2 = Dense(2048, activation='selu')(dense_layer_1)
  dense_layer_final = Dense(1, activation='sigmoid')(dense_layer_2)

  model3 = Model(inputs=var_input, outputs=dense_layer_final)
  model3.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
  return model3

# %%
for train, test in skf.split(x_data, y_data):
  target = create_VDCNN_model_3()
  target.fit(x_data[train], y_data[train],
            batch_size=batch_size,
            epochs=epochs,
            validation_data=(x_data[test], y_data[test]))
# Out:
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 71s 2ms/sample - loss: 1.8370 - accuracy: 0.5024 - val_loss: 0.6945 - val_accuracy: 0.5000
# Epoch 2/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.7126 - accuracy: 0.5336 - val_loss: 0.6941 - val_accuracy: 0.7068
# Epoch 3/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.5327 - accuracy: 0.7418 - val_loss: 0.4095 - val_accuracy: 0.8211
# Epoch 4/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 1.0498 - accuracy: 0.6646 - val_loss: 0.8578 - val_accuracy: 0.5000
# Epoch 5/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.7446 - accuracy: 0.4951 - val_loss: 0.6969 - val_accuracy: 0.5000
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 1.0418 - accuracy: 0.4993 - val_loss: 0.7094 - val_accuracy: 0.5000
# Epoch 2/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.6504 - accuracy: 0.5969 - val_loss: 0.6453 - val_accuracy: 0.7109
# Epoch 3/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 6.5925 - accuracy: 0.5750 - val_loss: 0.6965 - val_accuracy: 0.5036
# Epoch 4/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.7063 - accuracy: 0.5064 - val_loss: 0.6923 - val_accuracy: 0.5164
# Epoch 5/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.7129 - accuracy: 0.5098 - val_loss: 0.6939 - val_accuracy: 0.5124
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 1.1154 - accuracy: 0.5037 - val_loss: 0.7760 - val_accuracy: 0.4998
# Epoch 2/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.9897 - accuracy: 0.4998 - val_loss: 0.6960 - val_accuracy: 0.5000
# Epoch 3/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.7367 - accuracy: 0.5013 - val_loss: 0.6948 - val_accuracy: 0.5000
# Epoch 4/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.7383 - accuracy: 0.4976 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/5
# 40000/40000 [==============================] - 67s 2ms/sample - loss: 0.7382 - accuracy: 0.4990 - val_loss: 0.7555 - val_accuracy: 0.5000
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 71s 2ms/sample - loss: 1.1539 - accuracy: 0.5142 - val_loss: 7.7342 - val_accuracy: 0.5000
# Epoch 2/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 0.6985 - accuracy: 0.5684 - val_loss: 0.5318 - val_accuracy: 0.7397
# Epoch 3/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 0.4948 - accuracy: 0.7727 - val_loss: 0.7099 - val_accuracy: 0.6142
# Epoch 4/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 0.4145 - accuracy: 0.8260 - val_loss: 0.3439 - val_accuracy: 0.8565
# Epoch 5/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 0.6711 - accuracy: 0.6887 - val_loss: 0.9593 - val_accuracy: 0.5000
# train data shape: (40000,)
# test data shape: (10000,)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 74s 2ms/sample - loss: 1.1254 - accuracy: 0.5025 - val_loss: 0.6952 - val_accuracy: 0.5000
# Epoch 2/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 0.7341 - accuracy: 0.5020 - val_loss: 0.7371 - val_accuracy: 0.5000
# Epoch 3/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 0.7424 - accuracy: 0.5014 - val_loss: 0.7008 - val_accuracy: 0.5000
# Epoch 4/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 0.7470 - accuracy: 0.5015 - val_loss: 0.6935 - val_accuracy: 0.4999
# Epoch 5/5
# 40000/40000 [==============================] - 70s 2ms/sample - loss: 0.7383 - accuracy: 0.4986 - val_loss: 0.9110 - val_accuracy: 0.5000
